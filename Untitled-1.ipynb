# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
trend_data = pd.read_csv("Trend Data Dashboard.csv", index_col=0)
display(trend_data.head())
# Out:
#            Month                            Trend           Trend Type  \
# Platform
# TikTok    202006                            I Win  Lip Sync (dialogue)
# TikTok    202006               I am Jose Mourinho  Lip Sync (dialogue)
# TikTok    202006           I'm Gonna Live Forever     Lip Sync (music)
# TikTok    202006     That's My Life (Hilary Duff)  Lip Sync (dialogue)
# TikTok    202006  Hot New Bombshell (Love Island)  Lip Sync (dialogue)
#
#                              Music   Video Style   Theme Part of Song  \
# Platform
# TikTok                         NaN  Selfie Video  Comedy          NaN
# TikTok                         NaN  Selfie Video  Comedy          NaN
# TikTok    Fame - Irene Cara (1980)  Selfie Video  Comedy       Chorus
# TikTok                         NaN  Selfie Video  Comedy          NaN
# TikTok                         NaN  Selfie Video  Comedy          NaN
#
#           Video length in S Music Genre
# Platform
# TikTok                    7         NaN
# TikTok                    5         NaN
# TikTok                    8         Pop
# TikTok                    5         NaN
# TikTok                    6         NaN

# %% [markdown]
# Condense month value to exclude year since they are all in 2022

# %%
trend_data["Month"] = trend_data['Month'] % 100
display(trend_data.head(10))
# Out:
#           Month                                 Trend  \
# Platform
# TikTok        6                                 I Win
# TikTok        6                    I am Jose Mourinho
# TikTok        6                I'm Gonna Live Forever
# TikTok        6          That's My Life (Hilary Duff)
# TikTok        6       Hot New Bombshell (Love Island)
# TikTok        6               Guilty (Kim Kardashian)
# TikTok        6         Things People Have Said to Me
# TikTok        6       Benny and the Jets x Chiquitita
# TikTok        6  Feel No Ways (took one for the team)
# TikTok        6                      Credit Card Beep
#
#                         Trend Type  \
# Platform
# TikTok         Lip Sync (dialogue)
# TikTok         Lip Sync (dialogue)
# TikTok            Lip Sync (music)
# TikTok         Lip Sync (dialogue)
# TikTok         Lip Sync (dialogue)
# TikTok         Lip Sync (dialogue)
# TikTok    Dance + Lip Sync (music)
# TikTok                     Montage
# TikTok              Dance + Filter
# TikTok                     Act Out
#
#                                                       Music  \
# Platform
# TikTok                                                  NaN
# TikTok                                                  NaN
# TikTok                             Fame - Irene Cara (1980)
# TikTok                                                  NaN
# TikTok                                                  NaN
# TikTok                                                  NaN
# TikTok                     Happiness - Alexis Jordan (2010)
# TikTok    Benny and the Jets - Elton John (1974) Chiquit...
# TikTok                          Feel No Ways - Drake (2016)
# TikTok                                                  NaN
#
#                        Video Style      Theme        Part of Song  \
# Platform
# TikTok                Selfie Video     Comedy                 NaN
# TikTok                Selfie Video     Comedy                 NaN
# TikTok                Selfie Video     Comedy              Chorus
# TikTok                Selfie Video     Comedy                 NaN
# TikTok                Selfie Video     Comedy                 NaN
# TikTok                Selfie Video     Comedy                 NaN
# TikTok                Selfie Video     Comedy              Chorus
# TikTok     Photo/Video Compilation  Lifestyle  Prelude; Interlude
# TikTok    Video with Horace filter     Comedy         First verse
# TikTok                Selfie Video     Comedy                 NaN
#
#           Video length in S  Music Genre
# Platform
# TikTok                    7          NaN
# TikTok                    5          NaN
# TikTok                    8          Pop
# TikTok                    5          NaN
# TikTok                    6          NaN
# TikTok                    5          NaN
# TikTok                   24          R&B
# TikTok                   12    Rock; Pop
# TikTok                    5  Hip-Hop/Rap
# TikTok                    5          NaN

# %% [markdown]
# null values

# %%
null_counts = trend_data.isnull().sum()
null_counts
# Out:
# Month                 0
# Trend                 0
# Trend Type            0
# Music                14
# Video Style           0
# Theme                 0
# Part of Song         14
# Video length in S     0
# Music Genre          14
# dtype: int64

# %%
trend_data = trend_data.dropna()
trend_data.head()
# Out:
#           Month                                 Trend  \
# Platform
# TikTok        6                I'm Gonna Live Forever
# TikTok        6         Things People Have Said to Me
# TikTok        6       Benny and the Jets x Chiquitita
# TikTok        6  Feel No Ways (took one for the team)
# TikTok        6              Sands (Background Music)
#
#                         Trend Type  \
# Platform
# TikTok            Lip Sync (music)
# TikTok    Dance + Lip Sync (music)
# TikTok                     Montage
# TikTok              Dance + Filter
# TikTok        Text on Screen, Vlog
#
#                                                       Music  \
# Platform
# TikTok                             Fame - Irene Cara (1980)
# TikTok                     Happiness - Alexis Jordan (2010)
# TikTok    Benny and the Jets - Elton John (1974) Chiquit...
# TikTok                          Feel No Ways - Drake (2016)
# TikTok                              Sands - Lethilda (2021)
#
#                                     Video Style      Theme  \
# Platform
# TikTok                             Selfie Video     Comedy
# TikTok                             Selfie Video     Comedy
# TikTok                  Photo/Video Compilation  Lifestyle
# TikTok                 Video with Horace filter     Comedy
# TikTok    Selfie Video, Photo/Video Compilation  Lifestyle
#
#                 Part of Song  Video length in S  Music Genre
# Platform
# TikTok                Chorus                  8          Pop
# TikTok                Chorus                 24          R&B
# TikTok    Prelude; Interlude                 12    Rock; Pop
# TikTok           First verse                  5  Hip-Hop/Rap
# TikTok           First verse                  8          Pop

# %%
trend_data.drop('Music', axis=1, inplace=True)
trend_data.drop('Trend', axis=1, inplace=True)
display(trend_data.head(10))
# Out:
#           Month                            Trend Type  \
# Platform
# TikTok        6                      Lip Sync (music)
# TikTok        6              Dance + Lip Sync (music)
# TikTok        6                               Montage
# TikTok        6                        Dance + Filter
# TikTok        6                  Text on Screen, Vlog
# TikTok        7                               Montage
# TikTok        7                               Montage
# TikTok        7                      Transition, Vlog
# TikTok        7  Text on Screen + Lip Sync (dialogue)
# TikTok        8     Text on Screen + Lip Sync (music)
#
#                                     Video Style      Theme  \
# Platform
# TikTok                             Selfie Video     Comedy
# TikTok                             Selfie Video     Comedy
# TikTok                  Photo/Video Compilation  Lifestyle
# TikTok                 Video with Horace filter     Comedy
# TikTok    Selfie Video, Photo/Video Compilation  Lifestyle
# TikTok                  Photo/Video Compilation  Lifestyle
# TikTok                  Photo/Video Compilation  Lifestyle
# TikTok                             Selfie Video  Lifestyle
# TikTok                             Selfie Video     Comedy
# TikTok                             Selfie Video     Comedy
#
#                 Part of Song  Video length in S            Music Genre
# Platform
# TikTok                Chorus                  8                    Pop
# TikTok                Chorus                 24                    R&B
# TikTok    Prelude; Interlude                 12              Rock; Pop
# TikTok           First verse                  5            Hip-Hop/Rap
# TikTok           First verse                  8                    Pop
# TikTok                Chorus                 12               Pop Rock
# TikTok               Prelude                  7           Instrumental
# TikTok                Bridge                  7            Hip-Hop/Rap
# TikTok     Chorus; Beginning                 14  Country; Instrumental
# TikTok                Chorus                  7                    Pop
